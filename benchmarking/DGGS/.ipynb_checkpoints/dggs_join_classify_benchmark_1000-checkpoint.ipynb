# %%
from functools import partial
from math import sqrt
from pathlib import Path
import geopandas as gpd
import h3pandas
from itertools import product
import time
import timeit
import csv

# %%
input_dir = Path('vector_1000')
output_dir = Path.cwd()

# Get a list of all GPKG files in the folder
v_files = list(sorted(input_dir.glob('*.gpkg')))

# %%
# Specify the number of files to open
num_files_to_open = 500  #Layers to join
h3_res=14   #Setting h3 resolution
bench_runs=30  #Benchmark runs, should probably do 30

# %%
# Loop through each GPKG file, index and join
for i, file in enumerate(v_files[:num_files_to_open]):
        col_name = file.stem.split('_')[1]  # Extracting the column name from the file name
        df = gpd.read_file(file).to_crs(4326)
        df = df.h3.polyfill(h3_res, explode=True).drop(columns=['geometry'])
        df.columns = [col_name, *df.columns[1:]]  # Setting the column to the file
        df = df.set_index('h3_polyfill')
        if i == 0:
            combined_df = df.copy()
        else:
            combined_df = combined_df.join(df)

# %% [markdown]
# Benchmarking for joining

# %%
indexing_time= []
joining_time = []

def run_loop(num_files_to_open, v_files, h3_res):
    index_time= []
    join_time= []

    start_time = time.time()
    for i, file in enumerate(v_files[:num_files_to_open]):
        
        col_name = file.stem.split('_')[1]  # Extracting the column name from the file name
        df = gpd.read_file(file).to_crs(4326)

        #Indexing benchmark
        index_Stime=time.time()
        df = df.h3.polyfill(h3_res, explode=True).drop(columns=['geometry'])
        index_Etime=time.time()
        index_Ftime = index_Etime - index_Stime
        index_time.append(index_Ftime)

        #Joining benchmark
        join_Stime=time.time()
        df.columns = [col_name, *df.columns[1:]]  # Setting the column to the file
        df = df.set_index('h3_polyfill')
        if i == 0:
            combined_df = df.copy()
        else:
            combined_df = combined_df.join(df)
        join_Etime=time.time()
        join_Ftime = join_Etime - join_Stime
        join_time.append(join_Ftime)

    # Calculate and print the time taken for each run
    end_time = time.time()
    time_taken = end_time - start_time
    
    indexing_time.append(sum(index_time))
    joining_time.append(sum(join_time))
    print(f'Run: index time - {sum(index_time)} , joining time - {sum(join_time)} seconds, Total time- {time_taken} seconds')

# %%
timeit.timeit(lambda: run_loop(num_files_to_open, v_files, h3_res), number=bench_runs) #Benchmark run for joining
# Out:
# Run: index time - 172.73289442062378 , joining time - 160.90040230751038 seconds, Total time- 343.93572640419006 seconds
# Run: index time - 146.9152548313141 , joining time - 141.4498007297516 seconds, Total time- 298.34909534454346 seconds
# Run: index time - 152.06281232833862 , joining time - 153.66140246391296 seconds, Total time- 314.7922987937927 seconds
# Run: index time - 170.4612262248993 , joining time - 148.74919533729553 seconds, Total time- 331.0531008243561 seconds
# Run: index time - 173.91728734970093 , joining time - 163.836989402771 seconds, Total time- 347.859308719635 seconds
# Run: index time - 184.23043608665466 , joining time - 169.06189346313477 seconds, Total time- 363.59945821762085 seconds
# Run: index time - 190.3917510509491 , joining time - 164.29993295669556 seconds, Total time- 365.6229476928711 seconds
# Run: index time - 184.81684231758118 , joining time - 162.62133932113647 seconds, Total time- 358.10792875289917 seconds
# Run: index time - 193.38847756385803 , joining time - 162.3445007801056 seconds, Total time- 369.20561718940735 seconds
# Run: index time - 180.98300623893738 , joining time - 155.8649880886078 seconds, Total time- 348.21842408180237 seconds
# Run: index time - 190.03747534751892 , joining time - 158.75658202171326 seconds, Total time- 359.54888439178467 seconds
# Run: index time - 194.35741519927979 , joining time - 166.06106972694397 seconds, Total time- 372.2510108947754 seconds
# Run: index time - 149.28807306289673 , joining time - 125.45291233062744 seconds, Total time- 283.98871397972107 seconds
# Run: index time - 143.53943300247192 , joining time - 123.77155351638794 seconds, Total time- 285.1478922367096 seconds
# Run: index time - 143.6019251346588 , joining time - 126.32286286354065 seconds, Total time- 279.546733379364 seconds
# Run: index time - 174.64860200881958 , joining time - 139.01412177085876 seconds, Total time- 323.951509475708 seconds
# Run: index time - 149.8363058567047 , joining time - 126.8780779838562 seconds, Total time- 285.4374511241913 seconds
# Run: index time - 154.6283094882965 , joining time - 133.11559963226318 seconds, Total time- 298.058385848999 seconds
# Run: index time - 164.05061745643616 , joining time - 133.20350742340088 seconds, Total time- 307.2434358596802 seconds
# Run: index time - 149.11020708084106 , joining time - 128.61376357078552 seconds, Total time- 286.58705258369446 seconds
# Run: index time - 169.67465591430664 , joining time - 135.81867504119873 seconds, Total time- 316.30436849594116 seconds
# Run: index time - 140.5974304676056 , joining time - 122.65845608711243 seconds, Total time- 271.92372393608093 seconds
# Run: index time - 168.36688232421875 , joining time - 140.46736216545105 seconds, Total time- 318.4525089263916 seconds
# Run: index time - 171.471355676651 , joining time - 139.17803502082825 seconds, Total time- 324.023357629776 seconds
# Run: index time - 181.5508999824524 , joining time - 157.85211062431335 seconds, Total time- 350.3386890888214 seconds
# Run: index time - 188.3672273159027 , joining time - 171.47999906539917 seconds, Total time- 373.6270225048065 seconds
# Run: index time - 198.18714356422424 , joining time - 177.35282826423645 seconds, Total time- 387.88106513023376 seconds
# Run: index time - 162.53455185890198 , joining time - 134.89142489433289 seconds, Total time- 307.33204889297485 seconds
# Run: index time - 151.34012460708618 , joining time - 129.37323999404907 seconds, Total time- 293.13965249061584 seconds
# Run: index time - 168.25121331214905 , joining time - 133.74370312690735 seconds, Total time- 312.11449456214905 seconds
# 9779.67103019997

# %% [markdown]
# Defining classes

# %%
def is_prime(n):
    count = 0
    if n > 1:
        for i in range(1, n + 1):
            if n % i == 0:
                count += 1
    return count == 2

def is_polygonal(s, x):
    assert s > 2 and s % 1 == 0 and x % 1 == 0
    n = (sqrt(8 * (s - 2) * x + (s - 4) ** 2) + (s - 4)) / (2 * (s - 2))
    return n % 1 == 0

def is_fibonacci(n):
    a, b = 0,1
    while a < n:
        a, b = b, a + b
    return a == n

def is_perfect(n):
    sum = 1
    i = 2
    while i * i <= n:
        if n % i == 0:
            sum = sum + i + n/i
        i += 1
    return sum == n and n != 1

# %%
combined_df['sum'] = combined_df.select_dtypes(include='number').sum(axis=1)
classes = [
    ('is_prime', is_prime),
    ('is_triangular', partial(is_polygonal, 3)),
    ('is_rectangular', partial(is_polygonal, 4)),
    ('is_pentagonal', partial(is_polygonal, 5)),
    ('is_hexagonal', partial(is_polygonal, 6)),
    ('is_fibonacci', is_fibonacci),
    ('is_perfect', is_perfect),
]
for i, func in enumerate(classes):
    combined_df[func[0]] = combined_df['sum'].apply(func[1])

# %%
numerics = list(combined_df.select_dtypes(include='number'))
combined_df = combined_df.drop(columns=numerics)

# %%
combinations = list(product([True, False], repeat=7))
class_mapping = {tuple(row): f'Class_{i+1:03}' for i, row in enumerate(combinations)}

# %% [markdown]
# Benchmarking Classification

# %%
classify_time=[]
def classify_loop():
    
    start_time = time.time()

    bench_class = combined_df.apply(lambda row: class_mapping[tuple(row.astype(int))], axis=1) #This should remain the same, as cell count remains static   

    end_time = time.time()
    
    # Calculate and print the time taken for each run
    time_taken = end_time - start_time
    classify_time.append(time_taken)
    print(f'Run: Time taken - {time_taken} seconds')

# %%
timeit.timeit(lambda: classify_loop(), number=bench_runs) #Benchmark run for classifying
# Out:
# Run: Time taken - 5.607170581817627 seconds
# Run: Time taken - 5.705003023147583 seconds
# Run: Time taken - 5.963029384613037 seconds
# Run: Time taken - 6.307000637054443 seconds
# Run: Time taken - 5.99504280090332 seconds
# Run: Time taken - 5.932466745376587 seconds
# Run: Time taken - 5.850944519042969 seconds
# Run: Time taken - 5.86382532119751 seconds
# Run: Time taken - 5.790876626968384 seconds
# Run: Time taken - 5.597434997558594 seconds
# Run: Time taken - 5.5966222286224365 seconds
# Run: Time taken - 5.795292615890503 seconds
# Run: Time taken - 5.575953006744385 seconds
# Run: Time taken - 5.939817190170288 seconds
# Run: Time taken - 5.760294675827026 seconds
# Run: Time taken - 5.901980638504028 seconds
# Run: Time taken - 5.728919982910156 seconds
# Run: Time taken - 5.642453908920288 seconds
# Run: Time taken - 5.772467613220215 seconds
# Run: Time taken - 5.94134521484375 seconds
# Run: Time taken - 5.89833402633667 seconds
# Run: Time taken - 5.910422325134277 seconds
# Run: Time taken - 5.839777708053589 seconds
# Run: Time taken - 5.7680346965789795 seconds
# Run: Time taken - 6.032545804977417 seconds
# Run: Time taken - 5.915557861328125 seconds
# Run: Time taken - 5.82458758354187 seconds
# Run: Time taken - 5.850404739379883 seconds
# Run: Time taken - 5.878387689590454 seconds
# Run: Time taken - 5.710199356079102 seconds
# 174.90258839994203

# %% [markdown]
# Writing benchmark results

# %%
with open(f'DGGS_benchmark_{num_files_to_open}_layers.csv', 'w', newline='') as csvfile: #Writing benchmark results
    writer = csv.writer(csvfile)
    writer.writerow(['Run', 'Indexing(s)', 'Joining(s)','Classify(s)'])
    for i, (index_taken, join_taken, classify_taken) in enumerate(zip(indexing_time,joining_time, classify_time)):
        writer.writerow([i+1, index_taken, join_taken, classify_taken])

# %% [markdown]
# Applying classification

# %%
combined_df['class'] = combined_df.apply(lambda row: class_mapping[tuple(row.astype(int))], axis=1) #This should remain the same, as cell count remains static

# %%
h3_df=combined_df[['class']]

# %%
h3_df=h3_df.h3.h3_to_geo_boundary() #NOT going to benchmark these yet. But this should remain the same, as cell count remains static this whole cell should take roughly 10s

# %%
h3_df=h3_df.dissolve(by='class').reset_index().to_crs(2193)  #Technically this is traditional method, do we even include this? I think not.

# %% [markdown]
# Writing Geopackage output

# %%
output_dir.mkdir(parents=True, exist_ok=True)
output = (output_dir / f'DGGS_{num_files_to_open}_layers.gpkg')
# output.touch(exist_ok=True)
h3_df.to_file(output, layer='benchmarking', driver='GPKG', mode='w')

# %%
h3_df.plot('class', cmap='viridis')
# Out:
# <Axes: >
