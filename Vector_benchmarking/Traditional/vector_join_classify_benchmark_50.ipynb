# %%
from functools import partial
from math import sqrt
from pathlib import Path
import geopandas as gpd
from itertools import product
import time
import timeit
import csv

# %%
input_dir = Path('vector_1000')
output_dir = Path.cwd()

# Get a list of all GPKG files in the folder
v_files = list(sorted(input_dir.glob('*.gpkg')))

# %%
# Specify the number of files to open
num_files_to_open = 50
bench_runs=30  #Benchmark runs, should probably do 30

# %%
# Loop through each GPKG file and join
for i, file in enumerate(v_files[:num_files_to_open]):
    col_name = file.stem.split('_')[1]  # Extracting the column name from the file name
    df = gpd.read_file(file)
    df.columns = [col_name, *df.columns[1:]] #Setting the column to the file
    if i == 0:
        combined_df = df.copy()
    else:
        combined_df = gpd.overlay(combined_df, df)

# %% [markdown]
# Benchmarking for joining

# %%
joining_time = []
def run_loop(num_files_to_open, v_files):
    
    join_time= []
    start_time = time.time()
    for i, file in enumerate(v_files[:num_files_to_open]):
        col_name = file.stem.split('_')[1]  # Extracting the column name from the file name
        df = gpd.read_file(file)
        df.columns = [col_name, *df.columns[1:]] #Setting the column to the file

        #Joining benchmark
        join_Stime=time.time()
        if i == 0:
            combined_df = df.copy()
        else:
            combined_df = gpd.overlay(combined_df, df) 
        join_Etime=time.time()
        join_Ftime = join_Etime - join_Stime
        join_time.append(join_Ftime)
        
    end_time = time.time()
    
    # Calculate and print the time taken for each run
    time_taken = end_time - start_time
    joining_time.append(sum(join_time))
    print(f'Run: Joining time- {sum(join_time)} , Total Time taken - {time_taken} seconds')

# %%
timeit.timeit(lambda: run_loop(num_files_to_open, v_files), number=bench_runs) #Benchmark run for joining
# Out:
# Run: Joining time- 48.69519114494324 , Total Time taken - 49.210997343063354 seconds
# Run: Joining time- 48.92504692077637 , Total Time taken - 49.43484330177307 seconds
# Run: Joining time- 50.00598931312561 , Total Time taken - 50.52283334732056 seconds
# Run: Joining time- 56.864394187927246 , Total Time taken - 57.36015844345093 seconds
# Run: Joining time- 70.29723763465881 , Total Time taken - 70.97630834579468 seconds
# Run: Joining time- 64.63874363899231 , Total Time taken - 65.32648468017578 seconds
# Run: Joining time- 56.21412539482117 , Total Time taken - 57.469791412353516 seconds
# Run: Joining time- 57.53398156166077 , Total Time taken - 58.14751386642456 seconds
# Run: Joining time- 51.20283532142639 , Total Time taken - 51.752652645111084 seconds
# Run: Joining time- 47.012099266052246 , Total Time taken - 47.48993802070618 seconds
# Run: Joining time- 46.36459136009216 , Total Time taken - 46.88209104537964 seconds
# Run: Joining time- 46.830607652664185 , Total Time taken - 47.28502535820007 seconds
# Run: Joining time- 47.080106258392334 , Total Time taken - 47.5421838760376 seconds
# Run: Joining time- 47.80827593803406 , Total Time taken - 48.27363300323486 seconds
# Run: Joining time- 46.5795841217041 , Total Time taken - 47.04550242424011 seconds
# Run: Joining time- 48.57017254829407 , Total Time taken - 49.07475471496582 seconds
# Run: Joining time- 51.982178688049316 , Total Time taken - 52.47845530509949 seconds
# Run: Joining time- 65.75887036323547 , Total Time taken - 66.40634632110596 seconds
# Run: Joining time- 63.21133208274841 , Total Time taken - 63.83719444274902 seconds
# Run: Joining time- 65.14714169502258 , Total Time taken - 65.82131242752075 seconds
# Run: Joining time- 62.97535538673401 , Total Time taken - 63.60099744796753 seconds
# Run: Joining time- 65.97887134552002 , Total Time taken - 66.63922333717346 seconds
# Run: Joining time- 52.05901646614075 , Total Time taken - 52.6603729724884 seconds
# Run: Joining time- 50.217289209365845 , Total Time taken - 50.768388748168945 seconds
# Run: Joining time- 50.35407066345215 , Total Time taken - 50.954299211502075 seconds
# Run: Joining time- 49.750956773757935 , Total Time taken - 50.2849178314209 seconds
# Run: Joining time- 56.88317799568176 , Total Time taken - 57.44883108139038 seconds
# Run: Joining time- 62.997127294540405 , Total Time taken - 63.685097217559814 seconds
# Run: Joining time- 50.78423500061035 , Total Time taken - 51.31927728652954 seconds
# Run: Joining time- 57.26946663856506 , Total Time taken - 57.83865785598755 seconds
# 1658.1188241000054

# %% [markdown]
# Defining classes

# %%
def is_prime(n):
    count = 0
    if n > 1:
        for i in range(1, n + 1):
            if n % i == 0:
                count += 1
    return count == 2

def is_polygonal(s, x):
    assert s > 2 and s % 1 == 0 and x % 1 == 0
    n = (sqrt(8 * (s - 2) * x + (s - 4) ** 2) + (s - 4)) / (2 * (s - 2))
    return n % 1 == 0

def is_fibonacci(n):
    a, b = 0,1
    while a < n:
        a, b = b, a + b
    return a == n

def is_perfect(n):
    sum = 1
    i = 2
    while i * i <= n:
        if n % i == 0:
            sum = sum + i + n/i
        i += 1
    return sum == n and n != 1

# %%
combined_df['sum'] = combined_df.select_dtypes(include='number').sum(axis=1)
classes = [
    ('is_prime', is_prime),
    ('is_triangular', partial(is_polygonal, 3)),
    ('is_rectangular', partial(is_polygonal, 4)),
    ('is_pentagonal', partial(is_polygonal, 5)),
    ('is_hexagonal', partial(is_polygonal, 6)),
    ('is_fibonacci', is_fibonacci),
    ('is_perfect', is_perfect),
]
for i, func in enumerate(classes):
    combined_df[func[0]] = combined_df['sum'].apply(func[1])

# %%
numerics = list(combined_df.select_dtypes(include='number'))
combined_df = combined_df.drop(columns=numerics)

# %%
combinations = list(product([True, False], repeat=7))
class_mapping = {tuple(row): f'Class_{i+1:03}' for i, row in enumerate(combinations)}

# %% [markdown]
# Benchmarking Classification

# %%
classify_time=[]
def classify_loop():
    
    start_time = time.time()

    bench_class = combined_df[['is_prime','is_triangular','is_rectangular','is_pentagonal','is_hexagonal','is_fibonacci','is_perfect']].apply(lambda row: class_mapping[tuple(row.astype(int))], axis=1) #This should remain the same, as cell count remains static   

    end_time = time.time()
    
    # Calculate and print the time taken for each run
    time_taken = end_time - start_time
    classify_time.append(time_taken)
    print(f'Run: Time taken - {time_taken} seconds')

# %%
timeit.timeit(lambda: classify_loop(), number=bench_runs) #Benchmark run for classifying
# Out:
# Run: Time taken - 2.430591106414795 seconds
# Run: Time taken - 2.702610731124878 seconds
# Run: Time taken - 2.445234537124634 seconds
# Run: Time taken - 2.1469953060150146 seconds
# Run: Time taken - 2.1876437664031982 seconds
# Run: Time taken - 2.212007522583008 seconds
# Run: Time taken - 2.159524917602539 seconds
# Run: Time taken - 2.2102673053741455 seconds
# Run: Time taken - 2.61543869972229 seconds
# Run: Time taken - 2.4088099002838135 seconds
# Run: Time taken - 2.413578748703003 seconds
# Run: Time taken - 2.4623188972473145 seconds
# Run: Time taken - 2.3594818115234375 seconds
# Run: Time taken - 2.386073350906372 seconds
# Run: Time taken - 2.3127851486206055 seconds
# Run: Time taken - 2.3715620040893555 seconds
# Run: Time taken - 2.4965121746063232 seconds
# Run: Time taken - 2.501774787902832 seconds
# Run: Time taken - 2.4675564765930176 seconds
# Run: Time taken - 2.4208695888519287 seconds
# Run: Time taken - 2.386538028717041 seconds
# Run: Time taken - 2.595951795578003 seconds
# Run: Time taken - 2.6216275691986084 seconds
# Run: Time taken - 2.4826066493988037 seconds
# Run: Time taken - 2.389227867126465 seconds
# Run: Time taken - 2.626049757003784 seconds
# Run: Time taken - 2.4044241905212402 seconds
# Run: Time taken - 2.466414213180542 seconds
# Run: Time taken - 2.4603586196899414 seconds
# Run: Time taken - 2.6395363807678223 seconds
# 72.79113269993104

# %% [markdown]
# Writing benchmark results

# %%
with open(f'Vector_benchmark_{num_files_to_open}_layers.csv', 'w', newline='') as csvfile: #Writing benchmark results
    writer = csv.writer(csvfile)
    writer.writerow(['Run', 'Joining(s)','Classify(s)'])
    for i, (join_taken, classify_taken) in enumerate(zip(joining_time, classify_time)):
        writer.writerow([i+1, join_taken, classify_taken])

# %% [markdown]
# Applying classification

# %%
combined_df['class'] = combined_df[['is_prime','is_triangular','is_rectangular','is_pentagonal','is_hexagonal','is_fibonacci','is_perfect']].apply(lambda row: class_mapping[tuple(row.astype(int))], axis=1)
combined_df=combined_df[['class','geometry']]

# %%
output_dir.mkdir(parents=True, exist_ok=True)
output = (output_dir / f'Vector_{num_files_to_open}_layers.gpkg')
# output.touch(exist_ok=True)
combined_df.to_file(output, layer='benchmarking', driver='GPKG', mode='w')

# %%
combined_df.plot('class', cmap='viridis')
# Out:
# <Axes: >
