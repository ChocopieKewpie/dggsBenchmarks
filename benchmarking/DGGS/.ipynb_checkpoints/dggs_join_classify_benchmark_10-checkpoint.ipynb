# %%
from functools import partial
from math import sqrt
from pathlib import Path
import geopandas as gpd
import h3pandas
from itertools import product
import time
import timeit
import csv

# %%
input_dir = Path('vector_1000')
output_dir = Path.cwd()

# Get a list of all GPKG files in the folder
v_files = list(sorted(input_dir.glob('*.gpkg')))

# %%
# Specify the number of files to open
num_files_to_open = 10  #Layers to join
h3_res=14   #Setting h3 resolution
bench_runs=30  #Benchmark runs, should probably do 30

# %%
# Loop through each GPKG file, index and join
for i, file in enumerate(v_files[:num_files_to_open]):
        col_name = file.stem.split('_')[1]  # Extracting the column name from the file name
        df = gpd.read_file(file).to_crs(4326)
        df = df.h3.polyfill(h3_res, explode=True).drop(columns=['geometry'])
        df.columns = [col_name, *df.columns[1:]]  # Setting the column to the file
        df = df.set_index('h3_polyfill')
        if i == 0:
            combined_df = df.copy()
        else:
            combined_df = combined_df.join(df)

# %% [markdown]
# Benchmarking for joining

# %%
indexing_time= []
joining_time = []

def run_loop(num_files_to_open, v_files, h3_res):
    index_time= []
    join_time= []

    start_time = time.time()
    for i, file in enumerate(v_files[:num_files_to_open]):
        
        col_name = file.stem.split('_')[1]  # Extracting the column name from the file name
        df = gpd.read_file(file).to_crs(4326)

        #Indexing benchmark
        index_Stime=time.time()
        df = df.h3.polyfill(h3_res, explode=True).drop(columns=['geometry'])
        index_Etime=time.time()
        index_Ftime = index_Etime - index_Stime
        index_time.append(index_Ftime)

        #Joining benchmark
        join_Stime=time.time()
        df.columns = [col_name, *df.columns[1:]]  # Setting the column to the file
        df = df.set_index('h3_polyfill')
        if i == 0:
            combined_df = df.copy()
        else:
            combined_df = combined_df.join(df)
        join_Etime=time.time()
        join_Ftime = join_Etime - join_Stime
        join_time.append(join_Ftime)

    # Calculate and print the time taken for each run
    end_time = time.time()
    time_taken = end_time - start_time
    
    indexing_time.append(sum(index_time))
    joining_time.append(sum(join_time))
    print(f'Run: index time - {sum(index_time)} , joining time - {sum(join_time)} seconds, Total time- {time_taken} seconds')

# %%
timeit.timeit(lambda: run_loop(num_files_to_open, v_files, h3_res), number=bench_runs) #Benchmark run for joining
# Out:
# Run: index time - 3.041171073913574 , joining time - 0.5632045269012451 seconds, Total time- 3.745401620864868 seconds
# Run: index time - 3.0973825454711914 , joining time - 0.5435876846313477 seconds, Total time- 3.8137733936309814 seconds
# Run: index time - 3.0527219772338867 , joining time - 0.5415661334991455 seconds, Total time- 3.7658534049987793 seconds
# Run: index time - 3.0520434379577637 , joining time - 0.6079745292663574 seconds, Total time- 3.83703351020813 seconds
# Run: index time - 3.2327754497528076 , joining time - 0.6615283489227295 seconds, Total time- 4.054005146026611 seconds
# Run: index time - 3.0058467388153076 , joining time - 0.537562370300293 seconds, Total time- 3.7377920150756836 seconds
# Run: index time - 2.8612847328186035 , joining time - 0.4915504455566406 seconds, Total time- 3.502671241760254 seconds
# Run: index time - 3.169275999069214 , joining time - 0.5357646942138672 seconds, Total time- 3.854978322982788 seconds
# Run: index time - 2.9439988136291504 , joining time - 0.5132410526275635 seconds, Total time- 3.6006884574890137 seconds
# Run: index time - 2.8200550079345703 , joining time - 0.5145363807678223 seconds, Total time- 3.4941420555114746 seconds
# Run: index time - 2.7671701908111572 , joining time - 0.5014166831970215 seconds, Total time- 3.4336965084075928 seconds
# Run: index time - 2.8002235889434814 , joining time - 0.5655360221862793 seconds, Total time- 3.5108275413513184 seconds
# Run: index time - 2.7462520599365234 , joining time - 0.4683670997619629 seconds, Total time- 3.3579423427581787 seconds
# Run: index time - 2.7368762493133545 , joining time - 0.4694232940673828 seconds, Total time- 3.3500919342041016 seconds
# Run: index time - 2.7840733528137207 , joining time - 0.5176668167114258 seconds, Total time- 3.4520983695983887 seconds
# Run: index time - 2.71652889251709 , joining time - 0.5376157760620117 seconds, Total time- 3.399780750274658 seconds
# Run: index time - 2.703996181488037 , joining time - 0.48625802993774414 seconds, Total time- 3.35044527053833 seconds
# Run: index time - 2.7585465908050537 , joining time - 0.5522825717926025 seconds, Total time- 3.4311716556549072 seconds
# Run: index time - 2.735844612121582 , joining time - 0.4920158386230469 seconds, Total time- 3.3877830505371094 seconds
# Run: index time - 2.7148051261901855 , joining time - 0.48934364318847656 seconds, Total time- 3.355210542678833 seconds
# Run: index time - 2.7549870014190674 , joining time - 0.4741184711456299 seconds, Total time- 3.369922161102295 seconds
# Run: index time - 2.716096878051758 , joining time - 0.5520074367523193 seconds, Total time- 3.4416415691375732 seconds
# Run: index time - 3.0354349613189697 , joining time - 0.6616919040679932 seconds, Total time- 3.8692221641540527 seconds
# Run: index time - 3.3890175819396973 , joining time - 0.6336181163787842 seconds, Total time- 4.176623344421387 seconds
# Run: index time - 3.465679407119751 , joining time - 0.7009994983673096 seconds, Total time- 4.3392884731292725 seconds
# Run: index time - 3.3238472938537598 , joining time - 0.6705925464630127 seconds, Total time- 4.180805444717407 seconds
# Run: index time - 3.6296608448028564 , joining time - 0.7598690986633301 seconds, Total time- 4.577519178390503 seconds
# Run: index time - 3.614659309387207 , joining time - 0.7801542282104492 seconds, Total time- 4.587757587432861 seconds
# Run: index time - 3.4824750423431396 , joining time - 0.718827486038208 seconds, Total time- 4.39127254486084 seconds
# Run: index time - 3.461104393005371 , joining time - 0.7604074478149414 seconds, Total time- 4.421124458312988 seconds
# 113.06234309996944

# %% [markdown]
# Defining classes

# %%
def is_prime(n):
    count = 0
    if n > 1:
        for i in range(1, n + 1):
            if n % i == 0:
                count += 1
    return count == 2

def is_polygonal(s, x):
    assert s > 2 and s % 1 == 0 and x % 1 == 0
    n = (sqrt(8 * (s - 2) * x + (s - 4) ** 2) + (s - 4)) / (2 * (s - 2))
    return n % 1 == 0

def is_fibonacci(n):
    a, b = 0,1
    while a < n:
        a, b = b, a + b
    return a == n

def is_perfect(n):
    sum = 1
    i = 2
    while i * i <= n:
        if n % i == 0:
            sum = sum + i + n/i
        i += 1
    return sum == n and n != 1

# %%
combined_df['sum'] = combined_df.select_dtypes(include='number').sum(axis=1)
classes = [
    ('is_prime', is_prime),
    ('is_triangular', partial(is_polygonal, 3)),
    ('is_rectangular', partial(is_polygonal, 4)),
    ('is_pentagonal', partial(is_polygonal, 5)),
    ('is_hexagonal', partial(is_polygonal, 6)),
    ('is_fibonacci', is_fibonacci),
    ('is_perfect', is_perfect),
]
for i, func in enumerate(classes):
    combined_df[func[0]] = combined_df['sum'].apply(func[1])

# %%
numerics = list(combined_df.select_dtypes(include='number'))
combined_df = combined_df.drop(columns=numerics)

# %%
combinations = list(product([True, False], repeat=7))
class_mapping = {tuple(row): f'Class_{i+1:03}' for i, row in enumerate(combinations)}

# %% [markdown]
# Benchmarking Classification

# %%
classify_time=[]
def classify_loop():
    
    start_time = time.time()

    bench_class = combined_df.apply(lambda row: class_mapping[tuple(row.astype(int))], axis=1) #This should remain the same, as cell count remains static   

    end_time = time.time()
    
    # Calculate and print the time taken for each run
    time_taken = end_time - start_time
    classify_time.append(time_taken)
    print(f'Run: Time taken - {time_taken} seconds')

# %%
timeit.timeit(lambda: classify_loop(), number=bench_runs) #Benchmark run for classifying
# Out:
# Run: Time taken - 6.585996389389038 seconds
# Run: Time taken - 6.6140456199646 seconds
# Run: Time taken - 6.960167646408081 seconds
# Run: Time taken - 6.8639631271362305 seconds
# Run: Time taken - 7.0215418338775635 seconds
# Run: Time taken - 7.144588232040405 seconds
# Run: Time taken - 7.110213279724121 seconds
# Run: Time taken - 7.1127214431762695 seconds
# Run: Time taken - 7.289990425109863 seconds
# Run: Time taken - 6.967953681945801 seconds
# Run: Time taken - 6.960903882980347 seconds
# Run: Time taken - 7.18900203704834 seconds
# Run: Time taken - 6.878554821014404 seconds
# Run: Time taken - 7.190325975418091 seconds
# Run: Time taken - 7.21210789680481 seconds
# Run: Time taken - 7.177978038787842 seconds
# Run: Time taken - 6.653216123580933 seconds
# Run: Time taken - 7.01966667175293 seconds
# Run: Time taken - 7.274216413497925 seconds
# Run: Time taken - 7.655150651931763 seconds
# Run: Time taken - 8.182776689529419 seconds
# Run: Time taken - 7.847421407699585 seconds
# Run: Time taken - 8.127333164215088 seconds
# Run: Time taken - 7.879504919052124 seconds
# Run: Time taken - 9.003710985183716 seconds
# Run: Time taken - 8.887276649475098 seconds
# Run: Time taken - 8.751832485198975 seconds
# Run: Time taken - 8.786247730255127 seconds
# Run: Time taken - 8.395520448684692 seconds
# Run: Time taken - 8.651174545288086 seconds
# 225.4093547000084

# %% [markdown]
# Writing benchmark results

# %%
with open(f'DGGS_benchmark_{num_files_to_open}_layers.csv', 'w', newline='') as csvfile: #Writing benchmark results
    writer = csv.writer(csvfile)
    writer.writerow(['Run', 'Indexing(s)', 'Joining(s)','Classify(s)'])
    for i, (index_taken, join_taken, classify_taken) in enumerate(zip(indexing_time,joining_time, classify_time)):
        writer.writerow([i+1, index_taken, join_taken, classify_taken])

# %% [markdown]
# Applying classification

# %%
combined_df['class'] = combined_df.apply(lambda row: class_mapping[tuple(row.astype(int))], axis=1) #This should remain the same, as cell count remains static

# %%
h3_df=combined_df[['class']]

# %%
h3_df=h3_df.h3.h3_to_geo_boundary() #NOT going to benchmark these yet. But this should remain the same, as cell count remains static this whole cell should take roughly 10s

# %%
h3_df=h3_df.dissolve(by='class').reset_index().to_crs(2193)  #Technically this is traditional method, do we even include this? I think not.

# %% [markdown]
# Writing Geopackage output

# %%
output_dir.mkdir(parents=True, exist_ok=True)
output = (output_dir / f'DGGS_{num_files_to_open}_layers.gpkg')
# output.touch(exist_ok=True)
h3_df.to_file(output, layer='benchmarking', driver='GPKG', mode='w')

# %%
h3_df.plot('class', cmap='viridis')
# Out:
# <Axes: >
