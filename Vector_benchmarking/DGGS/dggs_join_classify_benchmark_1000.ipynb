# %%
from functools import partial
from math import sqrt
from pathlib import Path
import geopandas as gpd
import h3pandas
from itertools import product
import time
import timeit
import csv

# %%
input_dir = Path('vector_1000')
output_dir = Path.cwd()

# Get a list of all GPKG files in the folder
v_files = list(sorted(input_dir.glob('*.gpkg')))

# %%
# Specify the number of files to open
num_files_to_open = 1000  #Layers to join
h3_res=14   #Setting h3 resolution
bench_runs=30  #Benchmark runs, should probably do 30

# %%
# Loop through each GPKG file, index and join
for i, file in enumerate(v_files[:num_files_to_open]):
        col_name = file.stem.split('_')[1]  # Extracting the column name from the file name
        df = gpd.read_file(file).to_crs(4326)
        df = df.h3.polyfill(h3_res, explode=True).drop(columns=['geometry'])
        df.columns = [col_name, *df.columns[1:]]  # Setting the column to the file
        df = df.set_index('h3_polyfill')
        if i == 0:
            combined_df = df.copy()
        else:
            combined_df = combined_df.join(df)

# %% [markdown]
# Benchmarking for joining

# %%
indexing_time= []
joining_time = []

def run_loop(num_files_to_open, v_files, h3_res):
    index_time= []
    join_time= []

    start_time = time.time()
    for i, file in enumerate(v_files[:num_files_to_open]):
        
        col_name = file.stem.split('_')[1]  # Extracting the column name from the file name
        df = gpd.read_file(file).to_crs(4326)

        #Indexing benchmark
        index_Stime=time.time()
        df = df.h3.polyfill(h3_res, explode=True).drop(columns=['geometry'])
        index_Etime=time.time()
        index_Ftime = index_Etime - index_Stime
        index_time.append(index_Ftime)

        #Joining benchmark
        join_Stime=time.time()
        df.columns = [col_name, *df.columns[1:]]  # Setting the column to the file
        df = df.set_index('h3_polyfill')
        if i == 0:
            combined_df = df.copy()
        else:
            combined_df = combined_df.join(df)
        join_Etime=time.time()
        join_Ftime = join_Etime - join_Stime
        join_time.append(join_Ftime)

    # Calculate and print the time taken for each run
    end_time = time.time()
    time_taken = end_time - start_time
    
    indexing_time.append(sum(index_time))
    joining_time.append(sum(join_time))
    print(f'Run: index time - {sum(index_time)} , joining time - {sum(join_time)} seconds, Total time- {time_taken} seconds')

# %%
timeit.timeit(lambda: run_loop(num_files_to_open, v_files, h3_res), number=bench_runs) #Benchmark run for joining
# Out:
# Run: index time - 298.87820196151733 , joining time - 463.57963156700134 seconds, Total time- 781.8543832302094 seconds
# Run: index time - 337.9710912704468 , joining time - 494.20802664756775 seconds, Total time- 853.1968612670898 seconds
# Run: index time - 339.32783007621765 , joining time - 498.1742181777954 seconds, Total time- 859.0103299617767 seconds
# Run: index time - 310.2837624549866 , joining time - 489.7598361968994 seconds, Total time- 820.2092161178589 seconds
# Run: index time - 302.4562728404999 , joining time - 469.5496859550476 seconds, Total time- 790.7002031803131 seconds
# Run: index time - 329.66409397125244 , joining time - 502.32639479637146 seconds, Total time- 853.0537793636322 seconds
# Run: index time - 318.9583988189697 , joining time - 494.15962839126587 seconds, Total time- 835.6330666542053 seconds
# Run: index time - 332.0922269821167 , joining time - 493.53820180892944 seconds, Total time- 847.0085711479187 seconds
# Run: index time - 334.31239795684814 , joining time - 492.16770219802856 seconds, Total time- 847.7436833381653 seconds
# Run: index time - 313.80813121795654 , joining time - 506.6722116470337 seconds, Total time- 841.1408319473267 seconds
# Run: index time - 323.399151802063 , joining time - 527.4155943393707 seconds, Total time- 872.5697350502014 seconds
# Run: index time - 332.16216468811035 , joining time - 527.3013591766357 seconds, Total time- 879.9182124137878 seconds
# Run: index time - 334.9250183105469 , joining time - 516.324862241745 seconds, Total time- 872.5915682315826 seconds
# Run: index time - 320.1253309249878 , joining time - 522.8620557785034 seconds, Total time- 865.1771326065063 seconds
# Run: index time - 331.9359006881714 , joining time - 528.2546219825745 seconds, Total time- 882.6519072055817 seconds
# Run: index time - 316.15716910362244 , joining time - 515.1313970088959 seconds, Total time- 853.0967917442322 seconds
# Run: index time - 323.85711908340454 , joining time - 519.7963519096375 seconds, Total time- 873.9220731258392 seconds
# Run: index time - 319.23697090148926 , joining time - 510.01348876953125 seconds, Total time- 850.9516413211823 seconds
# Run: index time - 344.4046061038971 , joining time - 533.8637983798981 seconds, Total time- 901.1180708408356 seconds
# Run: index time - 340.2431662082672 , joining time - 533.101667881012 seconds, Total time- 896.375646352768 seconds
# Run: index time - 333.3782434463501 , joining time - 532.817296743393 seconds, Total time- 888.9919276237488 seconds
# Run: index time - 307.76333951950073 , joining time - 504.4351043701172 seconds, Total time- 838.668338060379 seconds
# Run: index time - 369.7277522087097 , joining time - 571.6254994869232 seconds, Total time- 965.9763634204865 seconds
# Run: index time - 398.5993506908417 , joining time - 591.3165035247803 seconds, Total time- 1014.277501821518 seconds
# Run: index time - 336.8999879360199 , joining time - 536.8970491886139 seconds, Total time- 896.6368088722229 seconds
# Run: index time - 314.3490240573883 , joining time - 515.7519612312317 seconds, Total time- 852.5732502937317 seconds
# Run: index time - 352.5857391357422 , joining time - 550.5346157550812 seconds, Total time- 925.4715690612793 seconds
# Run: index time - 327.9576277732849 , joining time - 533.1875422000885 seconds, Total time- 882.7875006198883 seconds
# Run: index time - 334.2481143474579 , joining time - 542.1941950321198 seconds, Total time- 899.0350575447083 seconds
# Run: index time - 314.8488218784332 , joining time - 525.3644716739655 seconds, Total time- 864.1154079437256 seconds
# 26110.323964799987

# %% [markdown]
# Defining classes

# %%
def is_prime(n):
    count = 0
    if n > 1:
        for i in range(1, n + 1):
            if n % i == 0:
                count += 1
    return count == 2

def is_polygonal(s, x):
    assert s > 2 and s % 1 == 0 and x % 1 == 0
    n = (sqrt(8 * (s - 2) * x + (s - 4) ** 2) + (s - 4)) / (2 * (s - 2))
    return n % 1 == 0

def is_fibonacci(n):
    a, b = 0,1
    while a < n:
        a, b = b, a + b
    return a == n

def is_perfect(n):
    sum = 1
    i = 2
    while i * i <= n:
        if n % i == 0:
            sum = sum + i + n/i
        i += 1
    return sum == n and n != 1

# %%
combined_df['sum'] = combined_df.select_dtypes(include='number').sum(axis=1)
classes = [
    ('is_prime', is_prime),
    ('is_triangular', partial(is_polygonal, 3)),
    ('is_rectangular', partial(is_polygonal, 4)),
    ('is_pentagonal', partial(is_polygonal, 5)),
    ('is_hexagonal', partial(is_polygonal, 6)),
    ('is_fibonacci', is_fibonacci),
    ('is_perfect', is_perfect),
]
for i, func in enumerate(classes):
    combined_df[func[0]] = combined_df['sum'].apply(func[1])

# %%
numerics = list(combined_df.select_dtypes(include='number'))
combined_df = combined_df.drop(columns=numerics)

# %%
combinations = list(product([True, False], repeat=7))
class_mapping = {tuple(row): f'Class_{i+1:03}' for i, row in enumerate(combinations)}

# %% [markdown]
# Benchmarking Classification

# %%
classify_time=[]
def classify_loop():
    
    start_time = time.time()

    bench_class = combined_df.apply(lambda row: class_mapping[tuple(row.astype(int))], axis=1) #This should remain the same, as cell count remains static   

    end_time = time.time()
    
    # Calculate and print the time taken for each run
    time_taken = end_time - start_time
    classify_time.append(time_taken)
    print(f'Run: Time taken - {time_taken} seconds')

# %%
timeit.timeit(lambda: classify_loop(), number=bench_runs) #Benchmark run for classifying
# Out:
# Run: Time taken - 7.286638975143433 seconds
# Run: Time taken - 7.117870092391968 seconds
# Run: Time taken - 7.115768194198608 seconds
# Run: Time taken - 7.047742605209351 seconds
# Run: Time taken - 6.580605745315552 seconds
# Run: Time taken - 6.401128053665161 seconds
# Run: Time taken - 6.967910289764404 seconds
# Run: Time taken - 7.096584796905518 seconds
# Run: Time taken - 7.245485067367554 seconds
# Run: Time taken - 7.093665838241577 seconds
# Run: Time taken - 7.376819133758545 seconds
# Run: Time taken - 7.267070055007935 seconds
# Run: Time taken - 7.11145806312561 seconds
# Run: Time taken - 7.098278045654297 seconds
# Run: Time taken - 7.140427350997925 seconds
# Run: Time taken - 7.11884617805481 seconds
# Run: Time taken - 7.176278829574585 seconds
# Run: Time taken - 7.102987766265869 seconds
# Run: Time taken - 7.336268663406372 seconds
# Run: Time taken - 7.136861801147461 seconds
# Run: Time taken - 7.001476526260376 seconds
# Run: Time taken - 7.115253925323486 seconds
# Run: Time taken - 6.912676811218262 seconds
# Run: Time taken - 6.947192192077637 seconds
# Run: Time taken - 6.602891445159912 seconds
# Run: Time taken - 6.346722364425659 seconds
# Run: Time taken - 5.588803291320801 seconds
# Run: Time taken - 5.624565362930298 seconds
# Run: Time taken - 5.667496204376221 seconds
# Run: Time taken - 5.6638782024383545 seconds
# 205.2957312000217

# %% [markdown]
# Writing benchmark results

# %%
with open(f'DGGS_benchmark_{num_files_to_open}_layers.csv', 'w', newline='') as csvfile: #Writing benchmark results
    writer = csv.writer(csvfile)
    writer.writerow(['Run', 'Indexing(s)', 'Joining(s)','Classify(s)'])
    for i, (index_taken, join_taken, classify_taken) in enumerate(zip(indexing_time,joining_time, classify_time)):
        writer.writerow([i+1, index_taken, join_taken, classify_taken])

# %% [markdown]
# Applying classification

# %%
combined_df['class'] = combined_df.apply(lambda row: class_mapping[tuple(row.astype(int))], axis=1) #This should remain the same, as cell count remains static

# %%
h3_df=combined_df[['class']]

# %%
h3_df=h3_df.h3.h3_to_geo_boundary() #NOT going to benchmark these yet. But this should remain the same, as cell count remains static this whole cell should take roughly 10s

# %%
h3_df=h3_df.dissolve(by='class').reset_index().to_crs(2193)  #Technically this is traditional method, do we even include this? I think not.

# %% [markdown]
# Writing Geopackage output

# %%
output_dir.mkdir(parents=True, exist_ok=True)
output = (output_dir / f'DGGS_{num_files_to_open}_layers.gpkg')
# output.touch(exist_ok=True)
h3_df.to_file(output, layer='benchmarking', driver='GPKG', mode='w')

# %%
h3_df.plot('class', cmap='viridis')
# Out:
# <Axes: >
